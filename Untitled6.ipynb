# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('sam.csv',error_bad_lines=False, engine="python")
print(data.shape)
data.head(10)
# Out:
# (1032, 6)
#               Name  "Team"         "Position"   H    W    Age
# 0    Adam Donachie   "BAL"          "Catcher"  74  180  22.99
# 1        Paul Bako   "BAL"          "Catcher"  74  215  34.69
# 2  Ramon Hernandez   "BAL"          "Catcher"  72  210  30.78
# 3     Kevin Millar   "BAL"    "First Baseman"  72  210  35.43
# 4      Chris Gomez   "BAL"    "First Baseman"  73  188  35.71
# 5    Brian Roberts   "BAL"   "Second Baseman"  69  176  29.39
# 6    Miguel Tejada   "BAL"        "Shortstop"  69  209  30.77
# 7      Melvin Mora   "BAL"    "Third Baseman"  71  200  35.07
# 8      Aubrey Huff   "BAL"    "Third Baseman"  76  231  30.19
# 9       Adam Stern   "BAL"       "Outfielder"  71  180  27.05

# %%
data=pd.read_csv('sample2.csv',error_bad_lines=False, engine="python")
print(data.shape)
data.head(10)
# Out:
# (1034, 6)
# Skipping line 1036: unexpected end of data
#               Name  "Team"         "Position"   "Height(inches)"  \
# 0    Adam Donachie   "BAL"          "Catcher"                 74
# 1        Paul Bako   "BAL"          "Catcher"                 74
# 2  Ramon Hernandez   "BAL"          "Catcher"                 72
# 3     Kevin Millar   "BAL"    "First Baseman"                 72
# 4      Chris Gomez   "BAL"    "First Baseman"                 73
# 5    Brian Roberts   "BAL"   "Second Baseman"                 69
# 6    Miguel Tejada   "BAL"        "Shortstop"                 69
# 7      Melvin Mora   "BAL"    "Third Baseman"                 71
# 8      Aubrey Huff   "BAL"    "Third Baseman"                 76
# 9       Adam Stern   "BAL"       "Outfielder"                 71
#
#    "Weight(lbs)"   "Age"
# 0            180   22.99
# 1            215   34.69
# 2            210   30.78
# 3            210   35.43
# 4            188   35.71
# 5            176   29.39
# ...

# %%
X=data['H'].values
Y=data['W'].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'H'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-836011b92909> in <module>
# ----> 1 X=data['H'].values
#       2 Y=data['W'].values
#
# ...

# %%
data=pd.read_csv('sam.csv',error_bad_lines=False, engine="python")
print(data.shape)
data.head(10)
# Out:
# (1032, 6)
#               Name  "Team"         "Position"   H    W    Age
# 0    Adam Donachie   "BAL"          "Catcher"  74  180  22.99
# 1        Paul Bako   "BAL"          "Catcher"  74  215  34.69
# 2  Ramon Hernandez   "BAL"          "Catcher"  72  210  30.78
# 3     Kevin Millar   "BAL"    "First Baseman"  72  210  35.43
# 4      Chris Gomez   "BAL"    "First Baseman"  73  188  35.71
# 5    Brian Roberts   "BAL"   "Second Baseman"  69  176  29.39
# 6    Miguel Tejada   "BAL"        "Shortstop"  69  209  30.77
# 7      Melvin Mora   "BAL"    "Third Baseman"  71  200  35.07
# 8      Aubrey Huff   "BAL"    "Third Baseman"  76  231  30.19
# 9       Adam Stern   "BAL"       "Outfielder"  71  180  27.05

# %%
X=data['H'].values
Y=data['W'].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'H'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-ea4e17db5d07> in <module>
# ----> 1 X=data['H'].value
#       2 Y=data[W].values
#
# ...
