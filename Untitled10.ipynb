# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
dataset=pd.read_csv('train.csv')

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
featur_na=[features for features in dataset.columns if dataset[features].isnull().sum()>1]
for feature in featur_na:
    print(feature, np.round(dataset[feature].isnull().mean(),2),'% missing values')
# Out:
# LotFrontage 0.18 % missing values
# Alley 0.94 % missing values
# MasVnrType 0.01 % missing values
# MasVnrArea 0.01 % missing values
# BsmtQual 0.03 % missing values
# BsmtCond 0.03 % missing values
# BsmtExposure 0.03 % missing values
# BsmtFinType1 0.03 % missing values
# BsmtFinType2 0.03 % missing values
# FireplaceQu 0.47 % missing values
# GarageType 0.06 % missing values
# GarageYrBlt 0.06 % missing values
# GarageFinish 0.06 % missing values
# GarageQual 0.06 % missing values
# GarageCond 0.06 % missing values
# PoolQC 1.0 % missing values
# Fence 0.81 % missing values
# MiscFeature 0.96 % missing values

# %%
for feature in featur_na:
    data=dataset.copy()
    data[feature]=np.where(data[feature].isnull(),1,0)
    
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %%
numerical_feature=[feature for feature in dataset.columns if dataset[feature].dtype != 'O']
print('Numerical variable is ' ,len(numerical_feature))
dataset[numerical_feature].head()
# Out:
# Numerical variable is  38
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
# ...

# %%
feature_year=[feature for feature in numerical_feature if 'Yr' in feature or 'Year' in feature]
feature_year
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
dataset.groupby('YrSold')['SalePrice'].median().plot()
feature_year

# %%
feature_year
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
 for feature in feature_year:
        if feature != 'YrSold':
            data=dataset.copy()
            data[feature]=data['YrSold']-data[feature]
            plt.scatter(data[feature],data['SalePrice'])
            plt.show()

# %%
discrete_feature=[feature for feature in numerical_feature if len(dataset[feature].unique())<25 and feature not in  feature_year+['Id']]
print(len(discrete_feature))
# Out:
# 17
